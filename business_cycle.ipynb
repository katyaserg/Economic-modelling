# %% [markdown]
# # Business cycle analysis

# %%
from utils import *

# %% [markdown]
# ## Load the data

# %%
raw_data = pd.read_csv("fred_md.csv").iloc[2:, :]
population = pd.read_csv("population.csv")
interest = pd.read_csv("interest_rate.csv")

raw_data["sasdate"] = pd.to_datetime(raw_data["sasdate"], format="%m/%d/%Y")
population["sasdate"] = pd.to_datetime(population["DATE"], format="%Y/%m/%d") + pd.DateOffset(months=2)
interest["sasdate"] = pd.to_datetime(interest["DATE"], format="%Y/%m/%d") + pd.DateOffset(months=2)

raw_data.index = raw_data["sasdate"]
raw_data = raw_data.drop(columns=["sasdate"])
population.index = population["sasdate"]
population = population.drop(columns=["sasdate", "DATE"])
interest.index = interest["sasdate"]
interest = interest.drop(columns=["sasdate", "DATE"])

raw_data = raw_data.join(population).join(interest)
raw_data.head()
# Out:
#               GDPC1  PCECC96  PCDGx   PCESVx   PCNDx  GPDIC1    FPIx  \
# sasdate
# 1959-03-01 3123.978 1927.430 76.627 1231.717 708.599 340.604 340.505
# 1959-06-01 3194.429 1957.197 79.511 1250.223 714.457 367.099 351.035
# 1959-09-01 3196.683 1977.643 81.048 1267.126 717.216 343.391 354.755
# 1959-12-01 3205.790 1979.871 77.176 1282.559 721.633 354.567 350.640
# 1960-03-01 3277.847 1998.811 79.659 1294.192 723.444 390.210 362.352
#
#             Y033RC1Q027SBEAx   PNFIx   PRFIx  A014RE1Q156NBEA    GCEC1  \
# sasdate
# 1959-03-01            49.278 169.880 229.223            0.800 1067.197
# 1959-06-01            50.753 174.764 237.236            1.400 1080.416
# 1959-09-01            52.406 179.471 232.792            0.100 1089.655
# 1959-12-01            52.300 178.970 226.201            0.800 1080.744
# 1960-03-01            54.120 185.190 233.161            2.100 1062.312
#
#             A823RL1Q225SBEA  FGRECPTx   SLCEx  EXPGSC1  IMPGSC1   DPIC96  \
# sasdate
# 1959-03-01           -7.700   518.215 491.277   93.393  129.446 2200.072
# 1959-06-01            7.600   539.534 492.496   92.647  135.745 2235.551
# 1959-09-01            5.500   526.314 492.820  101.582  137.041 2232.532
# 1959-12-01           -3.900   527.952 490.276   96.555  133.561 2248.432
# 1960-03-01          -14.200   576.251 498.482  108.999  138.606 2274.384
#
#             OUTNFB  OUTBS  OUTMS  INDPRO  IPFINAL  IPCONGD  IPMAT  IPDMAT  \
# sasdate
# 1959-03-01  16.700 16.905    NaN  22.361   22.434   31.856 20.641  12.528
# 1959-06-01  17.181 17.347    NaN  23.445   23.105   32.489 22.122  13.711
# 1959-09-01  17.154 17.314    NaN  22.486   23.417   32.851 19.827  11.404
# 1959-12-01  17.103 17.322    NaN  22.594   23.160   32.515 20.299  11.874
# 1960-03-01  17.612 17.753    NaN  23.956   24.023   33.781 22.284  13.745
#
#             IPNMAT  IPDCONGD  IPB51110SQ  IPNCONGD  IPBUSEQ  IPB51220SQ  TCU  \
# sasdate
# 1959-03-01  31.173    19.206      17.815    38.332    8.145      22.916  NaN
# 1959-06-01  32.808    19.930      18.762    38.879    8.706      23.174  NaN
# 1959-09-01  32.929    19.980      18.114    39.396    8.878      23.629  NaN
# 1959-12-01  32.607    18.948      15.500    39.609    8.689      24.134  NaN
# 1960-03-01  33.538    21.419      20.890    39.913    9.097      24.262  NaN
#
#             CUMFNS    PAYEMS    USPRIV    MANEMP    SRVPRD    USGOOD  DMANEMP  \
# sasdate
# 1959-03-01  81.372 52726.667 44609.000 15124.000 33808.333 18918.333 8848.000
# 1959-06-01  84.559 53517.333 45371.333 15475.333 34147.667 19369.667 9148.667
# 1959-09-01  80.499 53522.667 45325.000 15359.667 34312.667 19210.000 8988.333
# 1959-12-01  80.076 53722.000 45416.333 15343.667 34569.333 19152.667 8971.333
# 1960-03-01  84.472 54413.667 46027.667 15719.667 34924.000 19489.667 9316.000
#
#             NDMANEMP   USCONS    USEHS   USFIRE   USINFO    USPBS    USLAH  \
# sasdate
# 1959-03-01  6276.000 2995.333 2777.333 2422.667 1704.333 3556.333 3319.333
# 1959-06-01  6326.667 3090.667 2813.333 2446.667 1728.667 3608.333 3360.333
# 1959-09-01  6371.333 3074.333 2831.000 2464.667 1720.667 3618.000 3379.000
# 1959-12-01  6372.333 3033.000 2866.333 2483.667 1719.000 3645.333 3399.667
# 1960-03-01  6403.667 2985.000 2902.333 2505.000 1744.667 3693.667 3440.000
#
#              USSERV  USMINE     USTPU   USGOVT  USTRADE  USWTRADE  \
# sasdate
# 1959-03-01 1089.667 799.000 10821.000 8117.667 5387.733  2576.167
# 1959-06-01 1103.667 803.667 10940.667 8146.000 5439.833  2606.367
# 1959-09-01 1111.000 776.000 10990.667 8197.667 5481.600  2638.367
# 1959-12-01 1124.333 776.000 11025.333 8305.667 5508.633  2652.067
# 1960-03-01 1138.333 785.000 11114.000 8386.000 5568.367  2662.433
#
#             CES9091000001  CES9092000001  CES9093000001    CE16OV  CIVPART  \
# sasdate
# 1959-03-01       2337.000       1472.667       4308.000 63939.667   59.200
# 1959-06-01       2331.667       1478.000       4336.333 64772.000   59.267
# 1959-09-01       2331.667       1485.333       4380.667 64875.000   59.300
# 1959-12-01       2367.333       1500.667       4437.667 64927.333   59.333
# 1960-03-01       2396.667       1506.000       4483.333 65213.333   58.900
#
#             UNRATE  UNRATESTx  UNRATELTx  LNS14000012  LNS14000025  \
# sasdate
# 1959-03-01   5.833      4.724      1.087       13.500        5.133
# 1959-06-01   5.100      4.260      0.856       14.400        4.200
# 1959-09-01   5.267      4.607      0.692       15.167        4.467
# 1959-12-01   5.600      4.932      0.674       15.400        4.800
# 1960-03-01   5.133      4.526      0.647       14.433        4.367
#
#             LNS14000026  UEMPLT5  UEMP5TO14  UEMP15T26  UEMP27OV  LNS13023621  \
# sasdate
# 1959-03-01        5.600 1529.000   1142.000    556.333   738.000          NaN
# 1959-06-01        5.033 1498.333    967.333    404.333   584.667          NaN
# 1959-09-01        4.900 1600.000   1145.000    416.667   474.333          NaN
# 1959-12-01        5.100 1717.333   1206.333    464.667   463.667          NaN
# 1960-03-01        4.767 1578.333   1066.333    460.333   444.667          NaN
#
#             LNS13023557  LNS13023705  LNS13023569  LNS12032194  HOABS  HOAMS  \
# sasdate
# 1959-03-01          NaN          NaN          NaN     2703.333 55.272    NaN
# 1959-06-01          NaN          NaN          NaN     2496.000 56.567    NaN
# 1959-09-01          NaN          NaN          NaN     2591.333 56.048    NaN
# 1959-12-01          NaN          NaN          NaN     2754.333 56.005    NaN
# 1960-03-01          NaN          NaN          NaN     2492.333 55.868    NaN
#
#             HOANBS  AWHMAN  AWHNONAG  AWOTMAN     HWIx    HOUST  HOUST5F  \
# sasdate
# 1959-03-01  51.055  40.300       NaN    2.633 1434.000 1648.000  345.667
# 1959-06-01  52.021  40.600       NaN    2.900 1654.000 1530.333  297.667
# 1959-09-01  51.868  40.367       NaN    2.833 1655.000 1505.667  264.333
# 1959-12-01  51.883  40.100       NaN    2.667 1572.000 1457.333  252.000
# 1960-03-01  52.208  40.300       NaN    2.833 1942.000 1357.333  249.667
#
#              PERMIT  HOUSTMW  HOUSTNE  HOUSTS  HOUSTW  CMRMTSPLx    RSAFSx  \
# sasdate
# 1959-03-01      NaN  444.667  342.000 505.333 356.000 292979.719 18376.131
# 1959-06-01      NaN  363.000  263.000 513.667 390.667 300209.936 18687.961
# 1959-09-01      NaN  361.000  247.667 522.333 374.667 295560.774 18841.109
# 1959-12-01      NaN  342.000  252.000 511.667 351.667 291441.067 18493.327
# 1960-03-01 1045.000  315.667  229.667 473.667 338.333 302782.771 18803.081
#
#              AMDMNOx  ACOGNOx    AMDMUOx  ANDENOx  INVCQRMTSPL  PCECTPI  \
# sasdate
# 1959-03-01 91524.786      NaN 261588.027      NaN          NaN   16.056
# 1959-06-01 93556.436      NaN 271237.926      NaN          NaN   16.121
# 1959-09-01 85226.780      NaN 269681.541      NaN          NaN   16.219
# 1959-12-01 85762.617      NaN 273140.471      NaN          NaN   16.307
# 1960-03-01 85010.808      NaN 257082.014      NaN          NaN   16.328
#
#             PCEPILFE  GDPCTPI  GPDICTPI  IPDBS  DGDSRG3Q086SBEA  \
# sasdate
# 1959-03-01    16.703   16.316    24.235 19.610           26.335
# 1959-06-01    16.792   16.363    24.345 19.626           26.367
# 1959-09-01    16.904   16.432    24.423 19.699           26.450
# 1959-12-01    17.001   16.496    24.469 19.769           26.520
# 1960-03-01    17.055   16.527    24.497 19.834           26.482
#
#             DDURRG3Q086SBEA  DSERRG3Q086SBEA  DNDGRG3Q086SBEA  \
# sasdate
# 1959-03-01           56.963           11.344           17.792
# 1959-06-01           57.181           11.429           17.797
# 1959-09-01           57.171           11.538           17.873
# 1959-12-01           57.146           11.639           17.940
# 1960-03-01           57.062           11.691           17.915
#
#             DHCERG3Q086SBEA  DMOTRG3Q086SBEA  DFDHRG3Q086SBEA  \
# sasdate
# 1959-03-01           10.747           30.033           49.329
# 1959-06-01           10.823           30.234           49.568
# 1959-09-01           10.920           30.190           49.639
# 1959-12-01           11.021           30.158           49.648
# 1960-03-01           11.089           29.910           49.813
#
#             DREQRG3Q086SBEA  DODGRG3Q086SBEA  DFXARG3Q086SBEA  \
# sasdate
# 1959-03-01          265.357           29.561           16.446
# 1959-06-01          264.043           29.588           16.353
# 1959-09-01          264.088           29.582           16.390
# 1959-12-01          264.177           29.560           16.375
# 1959-12-01   15.812     3.990  4.230  4.640 4.917 4.583           NaN 4.570
# 1960-03-01   15.913     3.933  3.873  4.217 4.570 4.487           NaN 4.553
#
#              BAA  BAA10YM  MORTG10YRx  TB6M3Mx  GS1TB3Mx  GS10TB3Mx  \
# sasdate
# 1959-03-01 4.870    0.880         NaN    0.340     0.730      1.220
# 1959-06-01 4.953    0.697         NaN    0.370     0.920      1.260
# 1959-09-01 5.117    0.613         NaN    0.590     1.060      0.960
# 1959-12-01 5.273    0.690         NaN    0.410     0.690      0.350
# 1960-03-01 5.310    0.823         NaN    0.340     0.700      0.610
#
#             CPF3MTB3Mx  BOGMBASEREALx  M1REAL   M2REAL  BUSLOANSx  CONSUMERx  \
# sasdate
# 1959-03-01       0.530     172452.942 480.567  992.767    210.672    125.523
# 1959-06-01       0.600     172730.454 483.900 1005.833    216.372    129.411
# 1959-09-01       0.650     173784.496 484.833 1014.300    224.820    134.968
# 1959-12-01       0.530     173759.152 477.600 1011.700    228.220    139.942
# 1960-03-01       0.810     169861.782 475.900 1015.867    233.429    143.368
#
#             NONREVSLx  REALLNx  REVOLSLx  TOTALSLx  DRIWCIL  TABSHNOx  \
# sasdate
# 1959-03-01    296.323  150.819       NaN   296.323      NaN 12740.470
# 1959-06-01    303.996  154.854       NaN   303.996      NaN 12880.200
# 1959-09-01    313.680  157.532       NaN   313.680      NaN 12909.840
# 1959-12-01    323.835  160.013       NaN   323.835      NaN 13073.690
# 1960-03-01    330.778  162.426       NaN   330.778      NaN 13087.390
#
#             TLBSHNOx  LIABPIx  TNWBSHNOx   NWPIx   TARESAx  HNOREMQ027Sx  \
# sasdate
# 1959-03-01  1117.428   50.791  11623.040 528.303  9784.847   2955624.740
# 1959-06-01  1153.400   51.594  11726.800 524.560  9878.019   3002185.560
# 1959-09-01  1182.525   52.968  11727.320 525.292  9871.522   3038322.290
# 1959-12-01  1215.751   54.071  11857.940 527.387 10006.146   3067544.990
# 1960-03-01  1217.391   53.526  11870.000 521.900  9953.257   3134136.620
#
#             TFAABSHNOx  VIXCLSx  USSTHPI  SPCS10RSA  SPCS20RSA  TWEXAFEGSMTHx  \
# sasdate
# 1959-03-01    8703.900      NaN      NaN        NaN        NaN            NaN
# 1959-06-01    8791.320      NaN      NaN        NaN        NaN            NaN
# 1959-09-01    8784.180      NaN      NaN        NaN        NaN            NaN
# 1959-12-01    8921.090      NaN      NaN        NaN        NaN            NaN
# 1960-03-01    8862.630      NaN      NaN        NaN        NaN            NaN
#
#             EXUSEU  EXSZUSx  EXJPUSx  EXUSUKx  EXCAUSx  UMCSENTx  USEPUINDXM  \
# sasdate
# 1959-03-01     NaN    4.316  359.842    2.809    0.971       NaN         NaN
# 1959-06-01     NaN    4.319  359.842    2.814    0.962    95.300         NaN
# 1959-09-01     NaN    4.316  359.928    2.808    0.955       NaN         NaN
# 1959-12-01     NaN    4.334  360.231    2.803    0.950    93.800         NaN
# 1960-03-01     NaN    4.334  360.534    2.803    0.952   100.000         NaN
#
#             B020RE1Q156NBEA  B021RE1Q156NBEA  GFDEGDQ188S  GFDEBTNx  \
# sasdate
# 1959-03-01            4.300            4.200          NaN       NaN
# 1959-06-01            4.200            4.300          NaN       NaN
# 1959-09-01            4.600            4.400          NaN       NaN
# 1959-12-01            4.400            4.300          NaN       NaN
# 1960-03-01            4.800            4.300          NaN       NaN
#
#             IPMANSICS  IPB51222S  IPFUELS  UEMPMEAN  CES0600000007  TOTRESNS  \
# sasdate
# 1959-03-01     21.204     19.926   34.639    15.700         39.833    18.633
# 1959-06-01     22.226     20.315   34.456    14.833         40.233    18.600
# 1959-09-01     21.340     20.992   33.734    13.900         39.967    18.633
# 1959-12-01     21.417     21.498   34.272    13.033         39.733    18.733
# 1960-03-01     22.822     21.661   34.311    13.200         39.767    18.333
#
#             NONBORRES   GS5  TB3SMFFM  T5YFFM  AAAFFM  WPSID62  PPICMM  \
# sasdate
# 1959-03-01  18066.667 3.987     0.203   1.417   1.560   31.500  32.633
# 1959-06-01  17766.667 4.323    -0.083   1.240   1.270   31.500  32.867
# 1959-09-01  17666.667 4.683    -0.037   1.107   0.897   30.867  32.667
# 1959-12-01  17833.333 4.827     0.240   0.837   0.580   30.500  33.600
# 1960-03-01  17600.000 4.640    -0.060   0.707   0.620   30.500  34.233
#
#             CPIAPPSL  CPITRNSL  CPIMEDSL  CUSR0000SAC  CUSR0000SAD  \
# sasdate
# 1959-03-01    44.733    29.433    21.200       33.267       38.167
# 1959-06-01    44.900    29.733    21.400       33.267       38.367
# 1959-09-01    45.200    29.933    21.600       33.367       38.467
# 1959-12-01    45.300    30.100    21.767       33.500       38.500
# 1960-03-01    45.433    29.967    22.000       33.467       38.467
#
#             CUSR0000SAS  CPIULFSL  CUSR0000SA0L2  CUSR0000SA0L5  \
# sasdate
# 1959-03-01       22.967    28.900         30.700         29.600
# 1959-06-01       23.167    29.100         30.733         29.633
# 1959-09-01       23.400    29.267         30.933         29.833
# 1959-12-01       23.633    29.433         31.033         29.933
# 1960-03-01       23.800    29.600         31.100         29.967
#
#             CES0600000008  DTCOLNVHFNM  DTCTHFNM  INVEST  HWIURATIOx  \
# sasdate
# 1959-03-01          2.140     6486.667 12315.000  83.124       0.364
# 1959-06-01          2.167     6776.333 12685.333  80.413       0.474
# 1959-09-01          2.170     7278.000 13442.333  77.732       0.457
# 1959-12-01          2.180     7434.333 13917.000  76.091       0.408
# 1960-03-01          2.230     7404.667 14148.667  73.439       0.548
#
#               CLAIMSx   BUSINVx  ISRATIOx  CONSPIx  CP3M  COMPAPFF  PERMITNE  \
# sasdate
# 1959-03-01 278127.000 85230.520     1.543    0.126 3.300     0.730       NaN
# 1959-06-01 250541.000 87393.187     1.526    0.127 3.600     0.520       NaN
# 1959-09-01 274779.000 88795.998     1.577    0.131 4.190     0.620       NaN
# 1959-12-01 311618.000 89136.959     1.581    0.134 4.760     0.770       NaN
# 1960-03-01 285164.000 91445.753     1.574    0.135 4.690     0.750   214.667
#
#             PERMITMW  PERMITS  PERMITW  NIKKEI225  NASDAQCOM  CUSR0000SEHC  \
# sasdate
# 1959-03-01       NaN      NaN      NaN    708.709        NaN           NaN
# 1959-06-01       NaN      NaN      NaN    780.365        NaN           NaN
# 1959-09-01       NaN      NaN      NaN    862.039        NaN           NaN
# 1959-12-01       NaN      NaN      NaN    935.709        NaN           NaN
# 1960-03-01   232.667  303.000  294.667    984.469        NaN           NaN
#
#             TLBSNNCBx  TLBSNNCBBDIx  TTAABSNNCBx  TNWMVBSNNCBx  \
# sasdate
# 1959-03-01      2.230         0.019        2.940      1585.120
# 1959-06-01      2.330         0.019        2.980      1547.940
# 1959-09-01      2.300         0.019        2.990      1609.520
# 1959-12-01      2.450         0.019        3.010      1509.480
# 1960-03-01      2.330         0.019        3.020      1632.170
#
#             TNWMVBSNNCBBDIx   TLBSNNBx  TLBSNNBBDIx    TABSNNBx  TNWBSNNBx  \
# sasdate
# 1959-03-01         1341.570 315079.040   266668.100 2294094.850   1978.480
# 1959-06-01         1293.920 326994.800   273333.610 2302236.830   1974.690
# 1959-09-01         1320.090 335463.730   275139.480 2301883.340   1965.860
# 1959-12-01         1164.980 330365.720   254967.790 2296722.140   1965.780
# 1960-03-01         1325.980 343047.290   278692.550 2317787.640   1974.170
#
#             TNWBSNNBBDIx   CNCFx  S&P 500  S&P: indust  S&P div yield  \
# sasdate
# 1959-03-01      1674.490 118.154   55.517       59.140          3.176
# 1959-06-01      1650.640 119.632   57.507       61.587          3.101
# 1959-09-01      1612.350 121.925   58.730       63.060          3.072
# 1959-12-01      1517.140 129.572   57.763       62.020          3.157
# 1960-03-01      1603.820 123.092   56.277       60.193          3.385
#
#             S&P PE ratio               POPTHM   DFF
# sasdate
# 1959-03-01        18.621  176045.333333333333 2.577
# 1959-06-01        19.290  176726.666666666667 3.080
# 1959-09-01        18.954  177480.666666666667 3.573
# 1959-12-01        17.822  178267.666666666667 3.992
# 1960-03-01        16.828  179319.333333333333 3.931

# %% [markdown]
# ## Data preprocessing

# %%
data = raw_data[list(features_to_names.keys())].copy().iloc[:-1, :]
data = data.rename(columns=features_to_names).fillna(0)

data["population"] = data["population"].astype(float)
data["interest_rate"] = data["interest_rate"].astype(float)

milliard_factor_cols = ["gdp", "non_durable_consumption", "durable_consumption", "investment"]
thousand_factor_cols = ["employment", "population"]
for c in milliard_factor_cols:
    data[c] = data[c] * 1000_000_000
for c in thousand_factor_cols:
    data[c] = data[c] * 1000

data["gdp_cap"] = data["gdp"] / data["population"]
data["consumption_cap"] = (data["non_durable_consumption"] + data["durable_consumption"]) / data["population"]
data["investment_cap"] = data["investment"] / data["population"]
data["all_hours"] = data["all_bus_hours"] + data["all_manuf_hours"] + data["all_nonfarm_hours"]
data["productivity"] = data["gdp"] / data["employment"]
data
# Out:
#                           gdp  non_durable_consumption  durable_consumption  \
# sasdate
# 1959-03-01  3123978000000.000         708599400000.000      76626900000.000
# 1959-06-01  3194429000000.000         714457500000.000      79510700000.000
# 1959-09-01  3196683000000.000         717215900000.000      81048100000.000
# 1959-12-01  3205790000000.000         721633200000.000      77176000000.000
# 1960-03-01  3277847000000.000         723444000000.000      79659000000.000
# ...                       ...                      ...                  ...
# [257 rows x 18 columns]

# %% [markdown]
# ## Table 1

# %%
table1_raw_features = ["gdp", "non_durable_consumption", "durable_consumption", 
                   "all_hours", "avg_hours", 
                   "employment", "productivity", "average_hourly_earnings"]
table1_features = [f"{c}_trans" for c in table1_raw_features]

# %%
for c, c_trans in zip(table1_raw_features, table1_features):
    data[c_trans] = feat_to_transform[c](1 + data[c])

if np.isnan(data[table1_features[0]][0]):
    data = data.iloc[1:, :]

# %%
table1_std = data[table1_features].std() * 100

table1_data = []
for c in table1_features:
    table1_data.append(np.concatenate([ccf(data["gdp_trans"], data[c])[1:5][::-1],
                   ccf(data[c], data["gdp_trans"])[:5]]))

# %%
table1 = pd.DataFrame(table1_data)
table1.columns = ["t-4", "t-3", "t-2", "t-1", "t", "t+1", "t+2", "t+3", "t+4"]
table1["variable"] = table1_std.index
table1["sd%"] = table1_std.values
table1
# Out:
#      t-4   t-3   t-2   t-1     t   t+1   t+2    t+3    t+4  \
# 0  0.173 0.366 0.577 0.772 1.000 0.772 0.577  0.366  0.173
# 1  0.288 0.442 0.590 0.657 0.742 0.535 0.387  0.176 -0.016
# 2  0.429 0.548 0.657 0.735 0.722 0.465 0.288  0.075 -0.078
# 3  0.019 0.033 0.044 0.055 0.060 0.037 0.026  0.022 -0.022
# 4  0.339 0.484 0.605 0.682 0.762 0.461 0.162 -0.073 -0.254
# 5 -0.047 0.091 0.262 0.454 0.777 0.715 0.609  0.516  0.398
# 6  0.336 0.449 0.547 0.589 0.505 0.232 0.072 -0.132 -0.273
# 7  0.129 0.094 0.096 0.096 0.094 0.072 0.069  0.038  0.012
#
#                         variable    sd%
# 0                      gdp_trans  1.544
# 1  non_durable_consumption_trans  1.253
# 2      durable_consumption_trans  4.263
# 3                all_hours_trans 28.293
# 4                avg_hours_trans  0.896
# 5               employment_trans  1.348
# 6             productivity_trans  0.984
# 7  average_hourly_earnings_trans 17.020

# %% [markdown]
# ## Table 2

# %%
table2_raw_features = ["gdp_cap", "consumption_cap", 
                   "investment_cap", "avg_hours", 
                   "average_hourly_earnings", "interest_rate"]
table2_features = [f"{c}_trans" for c in table2_raw_features]

# %%
for c, c_trans in zip(table2_raw_features, table2_features):
    data[c_trans] = feat_to_transform[c](1 + data[c])

if np.isnan(data[table2_features[0]][0]):
    data = data.iloc[1:, :]

# %%
table2 = {}
table2["std_abs"] = data[table2_features].std().values
table2["std_rel"] = table2["std_abs"] / table2["std_abs"][0]

autocorr = []
for c in table2_features:
    autocorr.append(ccf(data[c], data[c])[1])
table2["autocorr"] = autocorr

corr = []
for c in table2_features:
    corr.append(ccf(data["gdp_cap_trans"], data[c])[0])
table2["corr"] = corr

table2 = pd.DataFrame(table2)
table2.index = table2_features
table2
# Out:
#                                std_abs  std_rel  autocorr  corr
# gdp_cap_trans                    0.016    1.000     0.775 1.000
# consumption_cap_trans            0.018    1.145     0.793 0.744
# investment_cap_trans             0.065    4.137     0.805 0.879
# avg_hours_trans                  0.009    0.574     0.715 0.761
# average_hourly_earnings_trans    0.170   10.901     0.727 0.096
# interest_rate_trans              3.652  233.902     0.974 0.181
